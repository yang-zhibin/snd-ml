# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.28/04

# %% [markdown]
# ## Scifi Cluster

# %%
file_path = "/eos/experiment/sndlhc/MonteCarlo/Neutrinos/Genie/sndlhc_13TeV_down_volTarget_100fb-1_SNDG18_02a_01_000/0/sndLHC.Genie-TGeant4_digCPP.root"

f = ROOT.TFile(file_path, 'read')
f.ls()
t = f.Get('cbmsim')
t.Print()
tb = ROOT.TBrowser()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 file_path = "/eos/experiment/sndlhc/MonteCarlo/Neutrinos/Genie/sndlhc_13TeV_down_volTarget_100fb-1_SNDG18_02a_01_000/0/sndLHC.Genie-TGeant4_digCPP.root"
# ----> 3 f = ROOT.TFile(file_path, 'read')
#       4 f.ls()
#       5 t = f.Get('cbmsim')
#
# NameError: name 'ROOT' is not defined

# %% [markdown]
# ## MuonReco

# %%
file_path = "/eos/experiment/sndlhc/MonteCarlo/Neutrinos/Genie/sndlhc_13TeV_down_volTarget_100fb-1_SNDG18_02a_01_000/0/sndLHC.Genie-TGeant4_digCPP_muonReco.root"

f = ROOT.TFile(file_path, 'read')
f.ls()
t = f.Get('cbmsim')
t.Print()
tb = ROOT.TBrowser()
# Out:
# TFile**		/eos/experiment/sndlhc/MonteCarlo/Neutrinos/Genie/sndlhc_13TeV_down_volTarget_100fb-1_SNDG18_02a_01_000/0/sndLHC.Genie-TGeant4_digCPP_muonReco.root
#  TFile*		/eos/experiment/sndlhc/MonteCarlo/Neutrinos/Genie/sndlhc_13TeV_down_volTarget_100fb-1_SNDG18_02a_01_000/0/sndLHC.Genie-TGeant4_digCPP_muonReco.root
#   KEY: TFolder	cbmout;1	Main Folder
#   KEY: TList	BranchList;1	Doubly linked list
#   KEY: TList	TimeBasedBranchList;1	Doubly linked list
#   KEY: FairFileHeader	FileHeader;1
#   KEY: TTree	cbmsim;1	/cbmout_0
# ******************************************************************************
# *Tree    :cbmsim    : /cbmout_0                                              *
# *Entries :      716 : Total =         9881076 bytes  File  Size =    2871278 *
# *        :          : Tree compression factor =   3.44                       *
# ******************************************************************************
# ...

# %%
# Look at MCTracks. These are the basic objects representing the simulated particles, transported through the media with Geant4.
t.GetEntry(1)
muonTracks = t.Reco_MuonTracks
muonTracks[0]
help(muonTracks[0])
dir(muonTracks[0])
# Out:
# Help on TObject in module cppyy._cpython_cppyy object:
#
# class TObject(CPPInstance)
#  |  Method resolution order:
#  |      TObject
#  |      CPPInstance
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  AbstractMethod(...)
#  |      void TObject::AbstractMethod(const char* method)
#  |
#  |  AppendPad(...)
#  |      void TObject::AppendPad(const char* option = "")
#  |
#  |  Browse(...)
#  |      void TObject::Browse(TBrowser* b)
#  |
#  |  CheckedHash(...)
#  |      unsigned long TObject::CheckedHash()
#  |
#  |  Class(...)
#  |      static TClass* TObject::Class()
#  |
#  |  ClassName(...)
#  |      const char* TObject::ClassName()
#  |
#  |  Class_Name(...)
#  |      static const char* TObject::Class_Name()
#  |
#  |  Class_Version(...)
#  |      static short TObject::Class_Version()
#  |
#  |  Clear(...)
#  |      void TObject::Clear(const char* = "")
#  |
#  |  Clone(...)
#  |      TObject* TObject::Clone(const char* newname = "")
#  |
#  |  Compare(...)
# ...

# %% [markdown]
# ├── cbmsim (Tree)
# │   ├── Reco_MuonTracks (branch)
# │   │   ├── Event1
# │   │   |   ├── Track1
# │   │   |   |   ├── Position
# │   │   |   |   ├── Mommentum
# │   │   |   ├── Track2
# │   │   ├── Event2
# │   │   |   ├── Track1
#
# ├── cbmsim (Tree)
# │   ├── ScifiCluster (branch)
# │   │   ├── Event1
# │   │   |   ├── Cluster1
# │   │   |   |   ├── Position (3D)
# │   │   |   ├── Cluster2
# │   │   ├── Event2
# │   │   |   ├── Cluster1

# %% [markdown]
# ‘’‘
# Help on Track in module ROOT._pythonization._titer object:
#
# class Track(cppyy.gbl.TObject)
#  |  Method resolution order:
#  |      Track
#  |      cppyy.gbl.TObject
#  |      cppyy.gbl.CPPInstance
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Class(...)
#  |      static TClass* genfit::Track::Class()
#  |
#  |  Class_Name(...)
#  |      static const char* genfit::Track::Class_Name()
#  |
#  |  Class_Version(...)
#  |      static short genfit::Track::Class_Version()
#  |
#  |  Clear(...)
#  |      void genfit::Track::Clear(const char* = "")
#  |
#  |  DeclFileLine(...)
#  |      static int genfit::Track::DeclFileLine()
#  |
#  |  DeclFileName(...)
#  |      static const char* genfit::Track::DeclFileName()
#  |
#  |  Dictionary(...)
#  |      static TClass* genfit::Track::Dictionary()
#  |
#  |  ImplFileLine(...)
#  |      static int genfit::Track::ImplFileLine()
#  |
#  |  ImplFileName(...)
#  |      static const char* genfit::Track::ImplFileName()
#  |
#  |  IsA(...)
#  |      TClass* genfit::Track::IsA()
#  |
#  |  Print(...)
#  |      void genfit::Track::Print(const char* = "")
#  |
#  |  ShowMembers(...)
#  |      void genfit::Track::ShowMembers(TMemberInspector& insp)
#  |
#  |  Streamer(...)
#  |      void genfit::Track::Streamer(TBuffer&)
#  |
#  |  StreamerNVirtual(...)
#  |      void genfit::Track::StreamerNVirtual(TBuffer& ClassDef_StreamerNVirtual_b)
#  |
#  |  __assign__(...)
#  |      genfit::Track& genfit::Track::operator=(genfit::Track)
#  |
#  |  __init__(...)
#  |      Track::Track()
#  |      Track::Track(const genfit::TrackCand& trackCand, const genfit::MeasurementFactory<genfit::AbsMeasurement>& factory, genfit::AbsTrackRep* rep = __n
# ull)
#  |      Track::Track(genfit::AbsTrackRep* trackRep, const TVectorT<double>& stateSeed)
#  |      Track::Track(genfit::AbsTrackRep* trackRep, const TVector3& posSeed, const TVector3& momSeed)
#  |      Track::Track(genfit::AbsTrackRep* trackRep, const TVectorT<double>& stateSeed, const TMatrixTSym<double>& covSeed)
#  |      Track::Track(const genfit::Track&)
#  |
#  |  __str__(...) from builtins.NoneType
#  |      Return str(self).
#  |
#  |  addTrackRep(...)
#  |      void genfit::Track::addTrackRep(genfit::AbsTrackRep* trackRep)
#  |
#  |  checkConsistency(...)
#  |      bool genfit::Track::checkConsistency()
#  |
#  |  constructTrackCand(...)
#  |      genfit::TrackCand* genfit::Track::constructTrackCand()
#  |
#  |  deleteBackwardInfo(...)
#  |      void genfit::Track::deleteBackwardInfo(int startId = 0, int endId = -1, const genfit::AbsTrackRep* rep = __null)
#  |
#  |  deleteFitterInfo(...)
#  |      void genfit::Track::deleteFitterInfo(int startId = 0, int endId = -1, const genfit::AbsTrackRep* rep = __null)
#  |
#  |  deleteForwardInfo(...)
#  |      void genfit::Track::deleteForwardInfo(int startId = 0, int endId = -1, const genfit::AbsTrackRep* rep = __null)
#  |
#  |  deleteMeasurementInfo(...)
#  |      void genfit::Track::deleteMeasurementInfo(int startId = 0, int endId = -1, const genfit::AbsTrackRep* rep = __null)
#  |
#  |  deletePoint(...)
#  |      void genfit::Track::deletePoint(int id)
#  |
#  |  deleteReferenceInfo(...)
#  |      void genfit::Track::deleteReferenceInfo(int startId = 0, int endId = -1, const genfit::AbsTrackRep* rep = __null)
#  |
#  |  deleteTrackRep(...)
#  |      void genfit::Track::deleteTrackRep(int id)
#  |
#  |  determineCardinalRep(...)
#  |      void genfit::Track::determineCardinalRep()
#  |
#  |  fixWeights(...)
#  |      void genfit::Track::fixWeights(genfit::AbsTrackRep* rep = __null, int startId = 0, int endId = -1)
#  |
#  |  getCardinalRep(...)
#  |      genfit::AbsTrackRep* genfit::Track::getCardinalRep()
#  |
#  |  getCardinalRepId(...)
#  |      unsigned int genfit::Track::getCardinalRepId()
#  |
#  |  getCovSeed(...)
#  |      const TMatrixTSym<double>& genfit::Track::getCovSeed()
#  |
#  |  getFitStatus(...)
#  |      genfit::FitStatus* genfit::Track::getFitStatus(const genfit::AbsTrackRep* rep = __null)
#  |
#  |  getFittedState(...)
#  |      const genfit::MeasuredStateOnPlane& genfit::Track::getFittedState(int id = 0, const genfit::AbsTrackRep* rep = __null, bool biased = true)
#  |
#  |  getIdForRep(...)
#  |      int genfit::Track::getIdForRep(const genfit::AbsTrackRep* rep)
#  |
#  |  getKalmanFitStatus(...)
#  |      genfit::KalmanFitStatus* genfit::Track::getKalmanFitStatus(const genfit::AbsTrackRep* rep = __null)
#  |
#  |  getMcTrackId(...)
#  |      int genfit::Track::getMcTrackId()
#  |
#  |  getNumPoints(...)
#  |      unsigned int genfit::Track::getNumPoints()
#  |
#  |  getNumPointsWithMeasurement(...)
#  |      unsigned int genfit::Track::getNumPointsWithMeasurement()
#  |
#  |  getNumReps(...)
#  |      unsigned int genfit::Track::getNumReps()
#  |
#  |  getPoint(...)
#  |      genfit::TrackPoint* genfit::Track::getPoint(int id)
#  |
#  |  getPointWithMeasurement(...)
#  |      genfit::TrackPoint* genfit::Track::getPointWithMeasurement(int id)
#  |
#  |  getPointWithMeasurementAndFitterInfo(...)
#  |      genfit::TrackPoint* genfit::Track::getPointWithMeasurementAndFitterInfo(int id, const genfit::AbsTrackRep* rep)
#  |
#  |  getPoints(...)
#  |      const vector<genfit::TrackPoint*>& genfit::Track::getPoints()
#  |
#  |  getPointsWithMeasurement(...)
#  |      const vector<genfit::TrackPoint*>& genfit::Track::getPointsWithMeasurement()
#  |
#  |  getStateSeed(...)
#  |      const TVectorT<double>& genfit::Track::getStateSeed()
#  |
#  |  getTOF(...)
#  |      double genfit::Track::getTOF(genfit::AbsTrackRep* rep = __null, int startId = 0, int endId = -1)
#  |
#  |  getTrackLen(...)
#  |      double genfit::Track::getTrackLen(genfit::AbsTrackRep* rep = __null, int startId = 0, int endId = -1)
#  |
#  |  getTrackRep(...)
#  |      genfit::AbsTrackRep* genfit::Track::getTrackRep(int id)
#  |
#  |  hasFitStatus(...)
#  |      bool genfit::Track::hasFitStatus(const genfit::AbsTrackRep* rep = __null)
#  |
#  |  hasKalmanFitStatus(...)
#  |      bool genfit::Track::hasKalmanFitStatus(const genfit::AbsTrackRep* rep = __null)
#  |
#  |  insertMeasurement(...)
#  |      void genfit::Track::insertMeasurement(genfit::AbsMeasurement* measurement, int id = -1)
#  |
#  |  insertPoint(...)
#  |      void genfit::Track::insertPoint(genfit::TrackPoint* point, int id = -1)
#  |
#  |  insertPoints(...)
#  |      void genfit::Track::insertPoints(vector<genfit::TrackPoint*> points, int id = -1)
#  |
#  |  mergeTrack(...)
#  |      void genfit::Track::mergeTrack(const genfit::Track* other, int id = -1)
#  |
#  |  prune(...)
#  |      void genfit::Track::prune(const char* = "CFLWRMIU")
#  |
#  |  reverseMomSeed(...)
#  |      void genfit::Track::reverseMomSeed()
#  |
#  |  reverseTrack(...)
#  |      void genfit::Track::reverseTrack()
#  |
#  |  reverseTrackPoints(...)
#  |      void genfit::Track::reverseTrackPoints()
#  |
#  |  setCardinalRep(...)
#  |      void genfit::Track::setCardinalRep(int id)
#  |
#  |  setCovSeed(...)
#  |      void genfit::Track::setCovSeed(const TMatrixTSym<double>& c)
#  |
#  |  setFitStatus(...)
#  |      void genfit::Track::setFitStatus(genfit::FitStatus* fitStatus, const genfit::AbsTrackRep* rep)
#  |
#  |  setMcTrackId(...)
#  |      void genfit::Track::setMcTrackId(int i)
#  |
#  |  setStateSeed(...)
#  |      void genfit::Track::setStateSeed(const TVectorT<double>& s)
#  |      void genfit::Track::setStateSeed(const TVector3& pos, const TVector3& mom)
#  |
#  |  sort(...)
#  |      bool genfit::Track::sort()
#  |
#  |  swap(...)
#  |      void genfit::Track::swap(genfit::Track& other)
#  |
#  |  switchPDGSigns(...)
#  |      void genfit::Track::switchPDGSigns(genfit::AbsTrackRep* rep = __null)
#  |
#  |  udpateSeed(...)
#  |      bool genfit::Track::udpateSeed(int id = 0, genfit::AbsTrackRep* rep = __null, bool biased = true)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from cppyy.gbl.TObject:
#  |
#  |  AbstractMethod(...)
#  |      void TObject::AbstractMethod(const char* method)
#  |
#  |  AppendPad(...)
#  |      void TObject::AppendPad(const char* option = "")
#  |
#  |  Browse(...)
#  |      void TObject::Browse(TBrowser* b)
#  |
#  |  CheckedHash(...)
#  |      unsigned long TObject::CheckedHash()
#  |
#  |  ClassName(...)
#  |      const char* TObject::ClassName()
#  |
#  |  Clone(...)
#  |      TObject* TObject::Clone(const char* newname = "")
#  |
#  |  Compare(...)
#  |      int TObject::Compare(const TObject* obj)
#  |
#  |  Copy(...)
#  |      void TObject::Copy(TObject& object)
#  |
#  |  Delete(...)
#  |      void TObject::Delete(const char* option = "")
#  |
#  |  DistancetoPrimitive(...)
#  |      int TObject::DistancetoPrimitive(int px, int py)
#  |
#  |  Draw(...)
#  |      void TObject::Draw(const char* option = "")
#  |
#  |  DrawClass(...)
#  |      void TObject::DrawClass()
#  |
#  |  DrawClone(...)
#  |      TObject* TObject::DrawClone(const char* option = "")
#  |
#  |  Dump(...)
#  |      void TObject::Dump()
#  |
#  |  Error(...)
#  |      void TObject::Error(const char* method, const char* msgfmt)
#  |
#  |  Execute(...)
#  |      void TObject::Execute(const char* method, const char* params, int* error = nullptr)
#  |      void TObject::Execute(TMethod* method, TObjArray* params, int* error = nullptr)
#  |
#  |  ExecuteEvent(...)
#  |      void TObject::ExecuteEvent(int event, int px, int py)
#  |
#  |  Fatal(...)
#  |      void TObject::Fatal(const char* method, const char* msgfmt)
#  |
#  |  FindObject(...)
#  |      TObject* TObject::FindObject(const char* name)
#  |      TObject* TObject::FindObject(const TObject* obj)
#  |
#  |  GetDrawOption(...)
#  |      const char* TObject::GetDrawOption()
#  |
#  |  GetDtorOnly(...)
#  |      static long TObject::GetDtorOnly()
#  |
#  |  GetIconName(...)
#  |      const char* TObject::GetIconName()
#  |
#  |  GetName(...)
#  |      const char* TObject::GetName()
#  |
#  |  GetObjectInfo(...)
#  |      char* TObject::GetObjectInfo(int px, int py)
#  |
#  |  GetObjectStat(...)
#  |      static bool TObject::GetObjectStat()
#  |
#  |  GetOption(...)
#  |      const char* TObject::GetOption()
#  |
#  |  GetTitle(...)
#  |      const char* TObject::GetTitle()
#  |
#  |  GetUniqueID(...)
#  |      unsigned int TObject::GetUniqueID()
#  |
#  |  HandleTimer(...)
#  |      bool TObject::HandleTimer(TTimer* timer)
#  |
#  |  HasInconsistentHash(...)
#  |      bool TObject::HasInconsistentHash()
#  |
#  |  Hash(...)
#  |      unsigned long TObject::Hash()
#  |
#  |  Info(...)
#  |      void TObject::Info(const char* method, const char* msgfmt)
#  |
#  |  InheritsFrom(...)
#  |      bool TObject::InheritsFrom(const char* classname)
#  |      bool TObject::InheritsFrom(const TClass* cl)
#  |
#  |  Inspect(...)
#  |      void TObject::Inspect()
#  |
#  |  InvertBit(...)
#  |      void TObject::InvertBit(unsigned int f)
#  |
#  |  IsDestructed(...)
#  |      bool TObject::IsDestructed()
#  |
#  |  IsEqual(...)
#  |      bool TObject::IsEqual(const TObject* obj)
#  |
#  |  IsFolder(...)
#  |      bool TObject::IsFolder()
#  |
#  |  IsOnHeap(...)
#  |      bool TObject::IsOnHeap()
#  |
#  |  IsSortable(...)
#  |      bool TObject::IsSortable()
#  |
#  |  IsZombie(...)
#  |      bool TObject::IsZombie()
#  |
#  |  MayNotUse(...)
#  |      void TObject::MayNotUse(const char* method)
#  |
#  |  Notify(...)
#  |      bool TObject::Notify()
#  |
#  |  Obsolete(...)
#  |      void TObject::Obsolete(const char* method, const char* asOfVers, const char* removedFromVers)
#  |
#  |  Paint(...)
#  |      void TObject::Paint(const char* option = "")
#  |
#  |  Pop(...)
#  |      void TObject::Pop()
#  |
#  |  Read(...)
#  |      int TObject::Read(const char* name)
#  |
#  |  RecursiveRemove(...)
#  |      void TObject::RecursiveRemove(TObject* obj)
#  |
#  |  ResetBit(...)
#  |      void TObject::ResetBit(unsigned int f)
#  |
#  |  SaveAs(...)
#  |      void TObject::SaveAs(const char* filename = "", const char* option = "")
#  |
#  |  SavePrimitive(...)
#  |      void TObject::SavePrimitive(basic_ostream<char,char_traits<char> >& out, const char* option = "")
#  |
#  |  SetBit(...)
#  |      void TObject::SetBit(unsigned int f, bool set)
#  |      void TObject::SetBit(unsigned int f)
#  |
#  |  SetDrawOption(...)
#  |      void TObject::SetDrawOption(const char* option = "")
#  |
#  |  SetDtorOnly(...)
#  |      static void TObject::SetDtorOnly(void* obj)
#  |
#  |  SetObjectStat(...)
#  |      static void TObject::SetObjectStat(bool stat)
#  |
#  |  SetUniqueID(...)
#  |      void TObject::SetUniqueID(unsigned int uid)
#  |
#  |  SysError(...)
#  |      void TObject::SysError(const char* method, const char* msgfmt)
#  |
#  |  TestBit(...)
#  |      bool TObject::TestBit(unsigned int f)
#  |
#  |  TestBits(...)
#  |      int TObject::TestBits(unsigned int f)
#  |
#  |  UseCurrentStyle(...)
#  |      void TObject::UseCurrentStyle()
#  |
#  |  Warning(...)
#  |      void TObject::Warning(const char* method, const char* msgfmt)
#  |
#  |  Write(...)
#  |      int TObject::Write(const char* name = nullptr, int option = 0, int bufsize = 0)
#  |      int TObject::Write(const char* name = nullptr, int option = 0, int bufsize = 0)
#  |
#  |  __contains__ = _contains(self, o)
#  |
#  |  __eq__(...) from builtins.NoneType
#  |      Return self==value.
#  |
#  |  __ge__ = _ge(self, o)
#  |
#  |  __gt__ = _gt(self, o)
#  |
#  |  __le__ = _le(self, o)
#  |
#  |  __lt__ = _lt(self, o)
#  |
#  |  __ne__(...) from builtins.NoneType
#  |      Return self!=value.
#  |
#  |  ls(...)
#  |      void TObject::ls(const char* option = "")
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from cppyy.gbl.TObject:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from cppyy.gbl.TObject:
#  |
#  |  kBitMask = 16777215
#  |
#  |  kCanDelete = 1
#  |
#  |  kCannotPick = 64
#  |
#  |  kHasUUID = 32
#  |
#  |  kInconsistent = 134217728
#  |
#  |  kInvalidObject = 8192
#  |
#  |  kIsOnHeap = 16777216
#  |
#  |  kIsReferenced = 16
#  |
#  |  kMustCleanup = 8
#  |
#  |  kNoContextMenu = 256
#  |
#  |  kNotDeleted = 33554432
#  |
#  |  kObjInCanvas = 8
#  |
#  |  kOverwrite = 2
#  |
#  |  kSingleKey = 1
#  |
#  |  kWriteDelete = 4
#  |
#  |  kZombie = 67108864
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from cppyy.gbl.CPPInstance:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __destruct__(...)
#  |
#  |  __dispatch__(...)
#  |      dispatch to selected overload
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __invert__(self, /)
#  |      ~self
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __neg__(self, /)
#  |      -self
#  |
#  |  __pos__(self, /)
#  |      +self
#  |
#  |  __radd__(self, value, /)
#  |      Return value+self.
#  |
#  |  __reduce__(...) from builtins.NoneType
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  __rsub__(self, value, /)
#  |      Return value-self.
#  |
#  |  __rtruediv__(self, value, /)
#  |      Return value/self.
#  |
#  |  __smartptr__(...)
#  |      get associated smart pointer, if any
#  |
#  |  __sub__(self, value, /)
#  |      Return self-value.
#  |
#  |  __truediv__(self, value, /)
#  |      Return self/value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from cppyy.gbl.CPPInstance:
#  |
#  |  __new__(*args, **kwargs) from cppyy.CPPScope
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from cppyy.gbl.CPPInstance:
#  |
